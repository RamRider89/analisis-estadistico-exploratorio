# %% [markdown]
# ## 🏠 metodo_workflow

# %% [markdown]
# ## 🧰 Carga de todas las librerías necesarias

# %%
import pandas as pd
import numpy as np

# warnings
import warnings

warnings.filterwarnings('ignore')

print("-" * 80)
print("¡Librerias importadas!")
print("-" * 80)

company_sales = {
    'SalesMonth': ['Jan', 'Feb', 'Mar', 'April'],
    'Company1': [150.0, 200.0, 300.0, 400.0],
    'Company2': [180.0, 250.0, np.nan, 500.0],
    'Company3': [400.0, 500.0, 600.0, 675.0]
}
# Out:
# --------------------------------------------------------------------------------
# ¡Librerias importadas!
# --------------------------------------------------------------------------------

# %%
import janitor  # upon import, functions are registered as part of pandas.

# This cleans the column names as well as removes any duplicate rows
df = pd.DataFrame.from_dict(company_sales).clean_names().remove_empty()
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import janitor  # upon import, functions are registered as part of pandas.
#       3 # This cleans the column names as well as removes any duplicate rows
#       4 df = pd.DataFrame.from_dict(company_sales).clean_names().remove_empty()
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/__init__.py:8
#       5 import pandas_flavor as pf  # noqa: F401
#       7 from .accessors import *  # noqa: F403, F401
# ----> 8 from .functions import *  # noqa: F403, F401
#       9 from .io import *  # noqa: F403, F401
#      10 from .math import *  # noqa: F403, F401
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/__init__.py:33
#      31 from .change_index_dtype import change_index_dtype
#      32 from .change_type import change_type
# ---> 33 from .clean_names import clean_names
#      34 from .coalesce import coalesce
#      35 from .collapse_levels import collapse_levels
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/clean_names.py:12
#       9 from pandas.api.types import is_scalar
#      11 from janitor.errors import JanitorError
# ---> 12 from janitor.functions.select import get_index_labels
#      13 from janitor.functions.utils import _is_str_or_cat
#      14 from janitor.utils import deprecated_alias
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/select.py:20
#      13 import pandas_flavor as pf
#      14 from pandas.api.types import (
#      15     is_bool_dtype,
#      16     is_datetime64_dtype,
#      17     is_list_like,
#      18     is_scalar,
#      19 )
# ---> 20 from pandas.core.col import Expression
#      21 from pandas.core.common import apply_if_callable, is_bool_indexer
#      22 from pandas.core.groupby.generic import DataFrameGroupBy, SeriesGroupBy
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/core/col.py:12
#       3 from collections.abc import (
#       4     Callable,
#       5     Hashable,
#       6 )
#       7 from typing import (
#       8     TYPE_CHECKING,
#       9     Any,
#      10 )
# ---> 12 from pandas.util._decorators import set_module
#      14 if TYPE_CHECKING:
#      15     from pandas import (
#      16         DataFrame,
#      17         Series,
#      18     )
#
# ImportError: cannot import name 'set_module' from 'pandas.util._decorators' (/home/idavid/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py)

# %%
from janitor import clean_names, remove_empty

df = pd.DataFrame.from_dict(company_sales)
df = clean_names(df)
df = remove_empty(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from janitor import clean_names, remove_empty
#       3 df = pd.DataFrame.from_dict(company_sales)
#       4 df = clean_names(df)
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/__init__.py:8
#       5 import pandas_flavor as pf  # noqa: F401
#       7 from .accessors import *  # noqa: F403, F401
# ----> 8 from .functions import *  # noqa: F403, F401
#       9 from .io import *  # noqa: F403, F401
#      10 from .math import *  # noqa: F403, F401
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/__init__.py:33
#      31 from .change_index_dtype import change_index_dtype
#      32 from .change_type import change_type
# ---> 33 from .clean_names import clean_names
#      34 from .coalesce import coalesce
#      35 from .collapse_levels import collapse_levels
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/clean_names.py:12
#       9 from pandas.api.types import is_scalar
#      11 from janitor.errors import JanitorError
# ---> 12 from janitor.functions.select import get_index_labels
#      13 from janitor.functions.utils import _is_str_or_cat
#      14 from janitor.utils import deprecated_alias
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/select.py:20
#      13 import pandas_flavor as pf
#      14 from pandas.api.types import (
#      15     is_bool_dtype,
#      16     is_datetime64_dtype,
#      17     is_list_like,
#      18     is_scalar,
#      19 )
# ---> 20 from pandas.core.col import Expression
#      21 from pandas.core.common import apply_if_callable, is_bool_indexer
#      22 from pandas.core.groupby.generic import DataFrameGroupBy, SeriesGroupBy
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/core/col.py:12
#       3 from collections.abc import (
#       4     Callable,
#       5     Hashable,
#       6 )
#       7 from typing import (
#       8     TYPE_CHECKING,
#       9     Any,
#      10 )
# ---> 12 from pandas.util._decorators import set_module
#      14 if TYPE_CHECKING:
#      15     from pandas import (
#      16         DataFrame,
#      17         Series,
#      18     )
#
# ImportError: cannot import name 'set_module' from 'pandas.util._decorators' (/home/idavid/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py)

# %%
from janitor import clean_names, remove_empty
df = (
    pd.DataFrame.from_dict(company_sales)
    .pipe(clean_names)
    .pipe(remove_empty)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from janitor import clean_names, remove_empty
#       2 df = (
#       3     pd.DataFrame.from_dict(company_sales)
#       4     .pipe(clean_names)
#       5     .pipe(remove_empty)
#       6 )
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/__init__.py:8
#       5 import pandas_flavor as pf  # noqa: F401
#       7 from .accessors import *  # noqa: F403, F401
# ----> 8 from .functions import *  # noqa: F403, F401
#       9 from .io import *  # noqa: F403, F401
#      10 from .math import *  # noqa: F403, F401
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/__init__.py:33
#      31 from .change_index_dtype import change_index_dtype
#      32 from .change_type import change_type
# ---> 33 from .clean_names import clean_names
#      34 from .coalesce import coalesce
#      35 from .collapse_levels import collapse_levels
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/clean_names.py:12
#       9 from pandas.api.types import is_scalar
#      11 from janitor.errors import JanitorError
# ---> 12 from janitor.functions.select import get_index_labels
#      13 from janitor.functions.utils import _is_str_or_cat
#      14 from janitor.utils import deprecated_alias
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/janitor/functions/select.py:20
#      13 import pandas_flavor as pf
#      14 from pandas.api.types import (
#      15     is_bool_dtype,
#      16     is_datetime64_dtype,
#      17     is_list_like,
#      18     is_scalar,
#      19 )
# ---> 20 from pandas.core.col import Expression
#      21 from pandas.core.common import apply_if_callable, is_bool_indexer
#      22 from pandas.core.groupby.generic import DataFrameGroupBy, SeriesGroupBy
#
# File ~/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/core/col.py:12
#       3 from collections.abc import (
#       4     Callable,
#       5     Hashable,
#       6 )
#       7 from typing import (
#       8     TYPE_CHECKING,
#       9     Any,
#      10 )
# ---> 12 from pandas.util._decorators import set_module
#      14 if TYPE_CHECKING:
#      15     from pandas import (
#      16         DataFrame,
#      17         Series,
#      18     )
#
# ImportError: cannot import name 'set_module' from 'pandas.util._decorators' (/home/idavid/dev/tecmilenio/python/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py)
